# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
train = pd.read_csv("house-prices-advanced-regression-techniques/train.csv")
test = pd.read_csv("house-prices-advanced-regression-techniques/test.csv")

# %% [markdown]
# ### Расшифровка признаков
#
#
# 1.SalePrice - the property's sale price in dollars. This is the target variable that you're trying to predict.цена продажи недвижимости в долларах. Это целевая переменная, которую вы пытаетесь предсказать.
#
# 2.MSSubClass: The building class.Класс здания
#
# 3.MSZoning: The general zoning classification.Общее местонахождение
#
# 4.LotFrontage: Linear feet of street connected to property. Площадь участка: футы улицы, подключенной к собственности.
#
# 5.LotArea: Lot size in square feet.Площадь участка: Размер участка в квадратных футах
#
# 6.Street: Type of road access Улица: Тип подъездной дороги
#
# 7.Alley: Type of alley access Переулок: Тип доступа к переулку
#
# 8.LotShape: General shape of property Форма участка: Общая форма собственности
#
# 9.LandContour: Flatness of the property Контур участка: Ровность участка
#
# 10.Utilities: Type of utilities available Коммунальные услуги: Тип доступных коммунальных услуг
#
# 11.LotConfig: Lot configuration Конфигурация лота(??)
#
# 12.LandSlope: Slope of property Уклон участка
#
# 13.Neighborhood: Physical locations within Ames city limits Район: Физическое местоположение в пределах города Эймс.
#
# 14.Condition1: Proximity to main road or railroad Условие1: Близость к главной дороге или железной дороге
#
# 15.Condition2: Proximity to main road or railroad (if a second is present)Условие 2: Близость к главной дороге или железной дороге (при наличии второго)
#
# 16.BldgType: Type of dwelling Тип здания: Тип жилого помещения
#
# 17.HouseStyle: Style of dwelling Стиль дома: Стиль жилища
#
# 18.OverallQual: Overall material and finish quality Общее качество: Общее качество материала и отделки
#
# 19.OverallCond: Overall condition rating Общее состояние: Оценка общего состояния
#
# 20.YearBuilt: Original construction date Год постройки: Первоначальная дата постройки
#
# 21.YearRemodAdd: Remodel date Дата реконструкции
#
# 22.RoofStyle: Type of roof Тип крыши
#
# 23.RoofMatl: Roof material Кровельный материал
#
# 24.Exterior1st: Exterior covering on house Внешний вид 1-й: Наружное покрытие дома
#
# 25.Exterior2nd: Exterior covering on house (if more than one material) Внешний вид 2-й: Наружное покрытие дома (если более одного материала)
#
# 26.MasVnrType: Masonry veneer type Тип облицовки каменной кладки
#
# 27.MasVnrArea: Masonry veneer area in square feet Площадь облицовки каменной кладки в квадратных футах
#
# 28.ExterQual: Exterior material quality Качество наружного материала
#
# 29.ExterCond: Present condition of the material on the exterior Текущее состояние материала на внешней стороне
#
# 30.Foundation: Type of foundation Тип фундамента
#
# 31.BsmtQual: Height of the basement Высота подвала
#
# 32.BsmtCond: General condition of the basement Общее состояние подвала
#
# 33.BsmtExposure: Walkout or garden level basement walls Стены подвала на уровне прохода или сада
#
# 34.BsmtFinType1: Quality of basement finished area Качество отделки подвала
#
# 35.BsmtFinSF1: Type 1 finished square feet Готовые квадратные футы типа 1
#
# 36.BsmtFinType2: Quality of second finished area (if present) Качество второй готовой области (если таковая имеется)
#
# 37.BsmtFinSF2: Type 2 finished square feet Готовые квадратные футы типа 2
#
# 38.BsmtUnfSF: Unfinished square feet of basement area Незаконченные квадратные футы подвальной площади
#
# 39.TotalBsmtSF: Total square feet of basement area Общая площадь подвала в квадратных футах
#
# 40.Heating: Type of heating Тип отопления
#
# 41.HeatingQC: Heating quality and condition Качество и состояние отопления
#
# 42.CentralAir: Central air conditioning Центральное кондиционирование воздуха
#
# 43.Electrical: Electrical system Электрическая система
#
# 44.1stFlrSF: First Floor square feet Площадь первого этажа в квадратных футах( у нас второй этаж)
#
# 45.2ndFlrSF: Second floor square feet Площадь второго этажа в квадратных футах( 3 этаж)
#
# 46.LowQualFinSF: Low quality finished square feet (all floors) Низкое качество готовых квадратных футов (все этажи)
#
# 47.GrLivArea: Above grade (ground) living area square feet Надземная (наземная) жилая площадь в квадратных футах
#
# 48.BsmtFullBath: Basement full bathrooms Подвал с  полными ванными комнатами (видимо ванна с санузлом)
#
# 49.BsmtHalfBath: Basement half bathrooms Половина ванных комнат в подвале (ванна без санузла)
#
# 50.FullBath: Full bathrooms above grade полные ванные комнаты выше первоого этажа( ванна с санузлом)
#
# 51.HalfBath: Half baths above grade  Половина ванных комнат выше первого этажа (только ванна без санузла)
#
# 52.Bedroom: Number of bedrooms above basement level Количество спален выше уровня подвала
#
# 53.Kitchen: Number of kitchens  Количество кухонь
#
# 54.KitchenQual: Kitchen quality  Качество кухни
#
# 55.TotRmsAbvGrd: Total rooms above grade (does not include bathrooms) Общее количество комнат выше первого этажа (не включает ванные комнаты)
#
# 56.Functional: Home functionality rating Оценка функциональности дома
#
# 57.Fireplaces: Number of fireplaces Количество каминов
#
# 58.FireplaceQu: Fireplace quality Качество камина
#
# 59.GarageType: Garage location Расположение гаража
#
# 60.GarageYrBlt: Year garage was built Год постройки гаража
#
# 61.GarageFinish: Interior finish of the garage Внутренняя отделка гаража
#
# 62.GarageCars: Size of garage in car capacity Размер гаража(вместимость машин)
#
# 63.GarageArea: Size of garage in square feet Размер гаража в квадратных футах
#
# 64.GarageQual: Garage quality Качество гаража
#
# 65.GarageCond: Garage condition Состояние гаража
#
# 66.PavedDrive: Paved driveway Мощеная подъездная дорога
#
# 67.WoodDeckSF: Wood deck area in square feet Площадь деревянной палубы в квадратных футах
#
# 68.OpenPorchSF: Open porch area in square feet Площадь открытой веранды в квадратных футах
#
# 69.EnclosedPorch: Enclosed porch area in square feet Площадь закрытой веранды в квадратных футах
#
# 70.3SsnPorch: Three season porch area in square feet Площадь трехсезонной веранды в квадратных футах
#
# 71.ScreenPorch: Screen porch area in square feet Площадь застекленной веранды(стекла) в квадратных футах
#
# 72.PoolArea: Pool area in square feet Площадь бассейна в квадратных футах
#
# 73.PoolQC: Pool quality Качество бассейна
#
# 74.Fence: Fence quality Качество забора
#
# 75.MiscFeature: Miscellaneous feature not covered in other categories Несоответствие: Разные признаки, не включенные в другие категории
#
# 76.MiscVal: $Value of miscellaneous feature Стоимость разных признаков
#
# 77.MoSold: Month Sold Месяц продажи
#
# 78.YrSold: Year Sold год продажи
#
# 79.SaleType: Type of sale тип продажи
#
# 80.SaleCondition: Condition of sale условия продажи

# %%
train.head(5).style.background_gradient(axis=None,cmap='YlOrRd')
# Out:
# <style type="text/css">
# #T_c79d1_row0_col0, #T_c79d1_row0_col1, #T_c79d1_row0_col3, #T_c79d1_row0_col17, #T_c79d1_row0_col18, #T_c79d1_row0_col26, #T_c79d1_row0_col34, #T_c79d1_row0_col36, #T_c79d1_row0_col37, #T_c79d1_row0_col38, #T_c79d1_row0_col43, #T_c79d1_row0_col44, #T_c79d1_row0_col45, #T_c79d1_row0_col47, #T_c79d1_row0_col48, #T_c79d1_row0_col49, #T_c79d1_row0_col50, #T_c79d1_row0_col51, #T_c79d1_row0_col52, #T_c79d1_row0_col54, #T_c79d1_row0_col56, #T_c79d1_row0_col61, #T_c79d1_row0_col62, #T_c79d1_row0_col66, #T_c79d1_row0_col67, #T_c79d1_row0_col68, #T_c79d1_row0_col69, #T_c79d1_row0_col70, #T_c79d1_row0_col71, #T_c79d1_row0_col75, #T_c79d1_row0_col76, #T_c79d1_row1_col0, #T_c79d1_row1_col1, #T_c79d1_row1_col3, #T_c79d1_row1_col17, #T_c79d1_row1_col18, #T_c79d1_row1_col26, #T_c79d1_row1_col36, #T_c79d1_row1_col37, #T_c79d1_row1_col44, #T_c79d1_row1_col45, #T_c79d1_row1_col47, #T_c79d1_row1_col48, #T_c79d1_row1_col49, #T_c79d1_row1_col50, #T_c79d1_row1_col51, #T_c79d1_row1_col52, #T_c79d1_row1_col54, #T_c79d1_row1_col56, #T_c79d1_row1_col61, #T_c79d1_row1_col62, #T_c79d1_row1_col66, #T_c79d1_row1_col67, #T_c79d1_row1_col68, #T_c79d1_row1_col69, #T_c79d1_row1_col70, #T_c79d1_row1_col71, #T_c79d1_row1_col75, #T_c79d1_row1_col76, #T_c79d1_row2_col0, #T_c79d1_row2_col1, #T_c79d1_row2_col3, #T_c79d1_row2_col17, #T_c79d1_row2_col18, #T_c79d1_row2_col26, #T_c79d1_row2_col34, #T_c79d1_row2_col36, #T_c79d1_row2_col37, #T_c79d1_row2_col38, #T_c79d1_row2_col43, #T_c79d1_row2_col44, #T_c79d1_row2_col45, #T_c79d1_row2_col47, #T_c79d1_row2_col48, #T_c79d1_row2_col49, #T_c79d1_row2_col50, #T_c79d1_row2_col51, #T_c79d1_row2_col52, #T_c79d1_row2_col54, #T_c79d1_row2_col56, #T_c79d1_row2_col61, #T_c79d1_row2_col62, #T_c79d1_row2_col66, #T_c79d1_row2_col67, #T_c79d1_row2_col68, #T_c79d1_row2_col69, #T_c79d1_row2_col70, #T_c79d1_row2_col71, #T_c79d1_row2_col75, #T_c79d1_row2_col76, #T_c79d1_row3_col0, #T_c79d1_row3_col1, #T_c79d1_row3_col3, #T_c79d1_row3_col17, #T_c79d1_row3_col18, #T_c79d1_row3_col26, #T_c79d1_row3_col34, #T_c79d1_row3_col36, #T_c79d1_row3_col37, #T_c79d1_row3_col38, #T_c79d1_row3_col43, #T_c79d1_row3_col44, #T_c79d1_row3_col45, #T_c79d1_row3_col47, #T_c79d1_row3_col48, #T_c79d1_row3_col49, #T_c79d1_row3_col50, #T_c79d1_row3_col51, #T_c79d1_row3_col52, #T_c79d1_row3_col54, #T_c79d1_row3_col56, #T_c79d1_row3_col61, #T_c79d1_row3_col62, #T_c79d1_row3_col66, #T_c79d1_row3_col67, #T_c79d1_row3_col68, #T_c79d1_row3_col69, #T_c79d1_row3_col70, #T_c79d1_row3_col71, #T_c79d1_row3_col75, #T_c79d1_row3_col76, #T_c79d1_row4_col0, #T_c79d1_row4_col1, #T_c79d1_row4_col3, #T_c79d1_row4_col17, #T_c79d1_row4_col18, #T_c79d1_row4_col26, #T_c79d1_row4_col34, #T_c79d1_row4_col36, #T_c79d1_row4_col37, #T_c79d1_row4_col45, #T_c79d1_row4_col47, #T_c79d1_row4_col48, #T_c79d1_row4_col49, #T_c79d1_row4_col50, #T_c79d1_row4_col51, #T_c79d1_row4_col52, #T_c79d1_row4_col54, #T_c79d1_row4_col56, #T_c79d1_row4_col61, #T_c79d1_row4_col62, #T_c79d1_row4_col66, #T_c79d1_row4_col67, #T_c79d1_row4_col68, #T_c79d1_row4_col69, #T_c79d1_row4_col70, #T_c79d1_row4_col71, #T_c79d1_row4_col75, #T_c79d1_row4_col76 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_c79d1_row0_col4 {
#   background-color: #fffac1;
#   color: #000000;
# }
# #T_c79d1_row0_col19, #T_c79d1_row0_col20, #T_c79d1_row0_col59, #T_c79d1_row0_col77, #T_c79d1_row1_col19, #T_c79d1_row1_col20, #T_c79d1_row1_col59, #T_c79d1_row1_col77, #T_c79d1_row2_col19, #T_c79d1_row2_col20, #T_c79d1_row2_col59, #T_c79d1_row2_col77, #T_c79d1_row3_col20, #T_c79d1_row3_col59, #T_c79d1_row3_col77, #T_c79d1_row4_col19, #T_c79d1_row4_col20, #T_c79d1_row4_col46, #T_c79d1_row4_col59, #T_c79d1_row4_col77 {
#   background-color: #fffec9;
#   color: #000000;
# }
# #T_c79d1_row0_col46, #T_c79d1_row1_col34, #T_c79d1_row1_col38, #T_c79d1_row1_col43, #T_c79d1_row1_col46, #T_c79d1_row2_col46, #T_c79d1_row3_col19, #T_c79d1_row3_col46, #T_c79d1_row4_col38, #T_c79d1_row4_col43, #T_c79d1_row4_col44 {
#   background-color: #fffecb;
#   color: #000000;
# }
# #T_c79d1_row0_col80 {
#   background-color: #c90823;
#   color: #f1f1f1;
# }
# #T_c79d1_row1_col4, #T_c79d1_row3_col4 {
#   background-color: #fffac0;
#   color: #000000;
# }
# #T_c79d1_row1_col80 {
#   background-color: #e8241f;
#   color: #f1f1f1;
# }
# #T_c79d1_row2_col4 {
#   background-color: #fff9bd;
#   color: #000000;
# }
# #T_c79d1_row2_col80 {
#   background-color: #b40026;
#   color: #f1f1f1;
# }
# #T_c79d1_row3_col80 {
#   background-color: #fd6e33;
#   color: #f1f1f1;
# }
# #T_c79d1_row4_col4 {
#   background-color: #fff7b9;
#   color: #000000;
# }
# #T_c79d1_row4_col80 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c79d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c79d1_level0_col0" class="col_heading level0 col0" >Id</th>
#       <th id="T_c79d1_level0_col1" class="col_heading level0 col1" >MSSubClass</th>
#       <th id="T_c79d1_level0_col2" class="col_heading level0 col2" >MSZoning</th>
#       <th id="T_c79d1_level0_col3" class="col_heading level0 col3" >LotFrontage</th>
#       <th id="T_c79d1_level0_col4" class="col_heading level0 col4" >LotArea</th>
#       <th id="T_c79d1_level0_col5" class="col_heading level0 col5" >Street</th>
#       <th id="T_c79d1_level0_col6" class="col_heading level0 col6" >Alley</th>
#       <th id="T_c79d1_level0_col7" class="col_heading level0 col7" >LotShape</th>
#       <th id="T_c79d1_level0_col8" class="col_heading level0 col8" >LandContour</th>
#       <th id="T_c79d1_level0_col9" class="col_heading level0 col9" >Utilities</th>
#       <th id="T_c79d1_level0_col10" class="col_heading level0 col10" >LotConfig</th>
#       <th id="T_c79d1_level0_col11" class="col_heading level0 col11" >LandSlope</th>
#       <th id="T_c79d1_level0_col12" class="col_heading level0 col12" >Neighborhood</th>
#       <th id="T_c79d1_level0_col13" class="col_heading level0 col13" >Condition1</th>
#       <th id="T_c79d1_level0_col14" class="col_heading level0 col14" >Condition2</th>
#       <th id="T_c79d1_level0_col15" class="col_heading level0 col15" >BldgType</th>
#       <th id="T_c79d1_level0_col16" class="col_heading level0 col16" >HouseStyle</th>
#       <th id="T_c79d1_level0_col17" class="col_heading level0 col17" >OverallQual</th>
#       <th id="T_c79d1_level0_col18" class="col_heading level0 col18" >OverallCond</th>
#       <th id="T_c79d1_level0_col19" class="col_heading level0 col19" >YearBuilt</th>
#       <th id="T_c79d1_level0_col20" class="col_heading level0 col20" >YearRemodAdd</th>
#       <th id="T_c79d1_level0_col21" class="col_heading level0 col21" >RoofStyle</th>
#       <th id="T_c79d1_level0_col22" class="col_heading level0 col22" >RoofMatl</th>
#       <th id="T_c79d1_level0_col23" class="col_heading level0 col23" >Exterior1st</th>
#       <th id="T_c79d1_level0_col24" class="col_heading level0 col24" >Exterior2nd</th>
#       <th id="T_c79d1_level0_col25" class="col_heading level0 col25" >MasVnrType</th>
#       <th id="T_c79d1_level0_col26" class="col_heading level0 col26" >MasVnrArea</th>
#       <th id="T_c79d1_level0_col27" class="col_heading level0 col27" >ExterQual</th>
#       <th id="T_c79d1_level0_col28" class="col_heading level0 col28" >ExterCond</th>
#       <th id="T_c79d1_level0_col29" class="col_heading level0 col29" >Foundation</th>
#       <th id="T_c79d1_level0_col30" class="col_heading level0 col30" >BsmtQual</th>
#       <th id="T_c79d1_level0_col31" class="col_heading level0 col31" >BsmtCond</th>
#       <th id="T_c79d1_level0_col32" class="col_heading level0 col32" >BsmtExposure</th>
#       <th id="T_c79d1_level0_col33" class="col_heading level0 col33" >BsmtFinType1</th>
#       <th id="T_c79d1_level0_col34" class="col_heading level0 col34" >BsmtFinSF1</th>
#       <th id="T_c79d1_level0_col35" class="col_heading level0 col35" >BsmtFinType2</th>
#       <th id="T_c79d1_level0_col36" class="col_heading level0 col36" >BsmtFinSF2</th>
#       <th id="T_c79d1_level0_col37" class="col_heading level0 col37" >BsmtUnfSF</th>
#       <th id="T_c79d1_level0_col38" class="col_heading level0 col38" >TotalBsmtSF</th>

# %%
train.shape
# Out:
# (1460, 81)

# %%
test.head(5).style.background_gradient(axis=None,cmap='YlOrRd')
# Out:
# <style type="text/css">
# #T_bea64_row0_col0, #T_bea64_row1_col0, #T_bea64_row2_col0, #T_bea64_row3_col0, #T_bea64_row4_col0 {
#   background-color: #fff0a8;
#   color: #000000;
# }
# #T_bea64_row0_col1, #T_bea64_row0_col17, #T_bea64_row0_col18, #T_bea64_row0_col26, #T_bea64_row0_col44, #T_bea64_row0_col45, #T_bea64_row0_col47, #T_bea64_row0_col48, #T_bea64_row0_col49, #T_bea64_row0_col50, #T_bea64_row0_col51, #T_bea64_row0_col52, #T_bea64_row0_col54, #T_bea64_row0_col56, #T_bea64_row0_col61, #T_bea64_row0_col67, #T_bea64_row0_col68, #T_bea64_row0_col69, #T_bea64_row0_col71, #T_bea64_row0_col75, #T_bea64_row0_col76, #T_bea64_row1_col1, #T_bea64_row1_col17, #T_bea64_row1_col18, #T_bea64_row1_col36, #T_bea64_row1_col44, #T_bea64_row1_col45, #T_bea64_row1_col47, #T_bea64_row1_col48, #T_bea64_row1_col49, #T_bea64_row1_col50, #T_bea64_row1_col51, #T_bea64_row1_col52, #T_bea64_row1_col54, #T_bea64_row1_col56, #T_bea64_row1_col61, #T_bea64_row1_col67, #T_bea64_row1_col68, #T_bea64_row1_col69, #T_bea64_row1_col70, #T_bea64_row1_col71, #T_bea64_row1_col76, #T_bea64_row2_col17, #T_bea64_row2_col18, #T_bea64_row2_col26, #T_bea64_row2_col36, #T_bea64_row2_col45, #T_bea64_row2_col47, #T_bea64_row2_col48, #T_bea64_row2_col49, #T_bea64_row2_col50, #T_bea64_row2_col51, #T_bea64_row2_col52, #T_bea64_row2_col54, #T_bea64_row2_col56, #T_bea64_row2_col61, #T_bea64_row2_col67, #T_bea64_row2_col68, #T_bea64_row2_col69, #T_bea64_row2_col70, #T_bea64_row2_col71, #T_bea64_row2_col75, #T_bea64_row2_col76, #T_bea64_row3_col17, #T_bea64_row3_col18, #T_bea64_row3_col26, #T_bea64_row3_col36, #T_bea64_row3_col45, #T_bea64_row3_col47, #T_bea64_row3_col48, #T_bea64_row3_col49, #T_bea64_row3_col50, #T_bea64_row3_col51, #T_bea64_row3_col52, #T_bea64_row3_col54, #T_bea64_row3_col56, #T_bea64_row3_col61, #T_bea64_row3_col67, #T_bea64_row3_col68, #T_bea64_row3_col69, #T_bea64_row3_col70, #T_bea64_row3_col71, #T_bea64_row3_col75, #T_bea64_row3_col76, #T_bea64_row4_col3, #T_bea64_row4_col17, #T_bea64_row4_col18, #T_bea64_row4_col26, #T_bea64_row4_col36, #T_bea64_row4_col44, #T_bea64_row4_col45, #T_bea64_row4_col47, #T_bea64_row4_col48, #T_bea64_row4_col49, #T_bea64_row4_col50, #T_bea64_row4_col51, #T_bea64_row4_col52, #T_bea64_row4_col54, #T_bea64_row4_col56, #T_bea64_row4_col61, #T_bea64_row4_col66, #T_bea64_row4_col68, #T_bea64_row4_col69, #T_bea64_row4_col71, #T_bea64_row4_col75, #T_bea64_row4_col76 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_bea64_row0_col3, #T_bea64_row1_col3, #T_bea64_row1_col26, #T_bea64_row2_col1, #T_bea64_row2_col3, #T_bea64_row3_col1, #T_bea64_row3_col3, #T_bea64_row4_col67 {
#   background-color: #fffecb;
#   color: #000000;
# }
# #T_bea64_row0_col4 {
#   background-color: #cf0c21;
#   color: #f1f1f1;
# }
# #T_bea64_row0_col19, #T_bea64_row0_col20, #T_bea64_row0_col59, #T_bea64_row1_col19, #T_bea64_row1_col20, #T_bea64_row1_col59, #T_bea64_row2_col19, #T_bea64_row2_col20, #T_bea64_row2_col59, #T_bea64_row3_col19, #T_bea64_row3_col20, #T_bea64_row3_col59, #T_bea64_row4_col19, #T_bea64_row4_col20, #T_bea64_row4_col59 {
#   background-color: #ffeb9c;
#   color: #000000;
# }
# #T_bea64_row0_col34, #T_bea64_row2_col62, #T_bea64_row3_col62 {
#   background-color: #fffac1;
#   color: #000000;
# }
# #T_bea64_row0_col36, #T_bea64_row0_col66, #T_bea64_row0_col70, #T_bea64_row2_col37, #T_bea64_row4_col1, #T_bea64_row4_col70 {
#   background-color: #fffec9;
#   color: #000000;
# }
# #T_bea64_row0_col37, #T_bea64_row4_col34 {
#   background-color: #fffdc6;
#   color: #000000;
# }
# #T_bea64_row0_col38 {
#   background-color: #fff7b7;
#   color: #000000;
# }
# #T_bea64_row0_col43, #T_bea64_row0_col46, #T_bea64_row1_col34, #T_bea64_row2_col38, #T_bea64_row2_col43, #T_bea64_row3_col38, #T_bea64_row3_col43 {
#   background-color: #fff6b6;
#   color: #000000;
# }
# #T_bea64_row0_col62 {
#   background-color: #fff8ba;
#   color: #000000;
# }
# #T_bea64_row0_col77, #T_bea64_row1_col77, #T_bea64_row2_col77, #T_bea64_row3_col77, #T_bea64_row4_col77 {
#   background-color: #ffea9b;
#   color: #000000;
# }
# #T_bea64_row1_col4 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_bea64_row1_col37, #T_bea64_row1_col66 {
#   background-color: #fffbc2;
#   color: #000000;
# }
# #T_bea64_row1_col38, #T_bea64_row1_col43, #T_bea64_row1_col46 {
#   background-color: #fff2ac;
#   color: #000000;
# }
# #T_bea64_row1_col62, #T_bea64_row3_col37 {
#   background-color: #fffcc5;
#   color: #000000;
# }
# #T_bea64_row1_col75 {
#   background-color: #bb0026;
#   color: #f1f1f1;
# }
# #T_bea64_row2_col4 {
#   background-color: #8d0026;
#   color: #f1f1f1;
# }
# #T_bea64_row2_col34 {
#   background-color: #fff7b9;
#   color: #000000;
# }
# #T_bea64_row2_col44, #T_bea64_row3_col44 {
#   background-color: #fff8bb;
#   color: #000000;
# }
# #T_bea64_row2_col46 {
#   background-color: #ffefa4;
#   color: #000000;
# }
# #T_bea64_row2_col66 {
#   background-color: #fffdc8;
#   color: #000000;
# }
# #T_bea64_row3_col4 {
#   background-color: #ed2e21;
#   color: #f1f1f1;
# }
# #T_bea64_row3_col34 {
#   background-color: #fff9be;
#   color: #000000;
# }
# #T_bea64_row3_col46 {
#   background-color: #ffefa5;
#   color: #000000;
# }
# #T_bea64_row3_col66 {
#   background-color: #fffcc4;
#   color: #000000;
# }
# #T_bea64_row4_col4 {
#   background-color: #feba55;
#   color: #000000;
# }
# #T_bea64_row4_col37 {
#   background-color: #fff5b3;
#   color: #000000;
# }
# #T_bea64_row4_col38, #T_bea64_row4_col43, #T_bea64_row4_col46 {
#   background-color: #fff3ae;
#   color: #000000;
# }
# #T_bea64_row4_col62 {
#   background-color: #fffac0;
#   color: #000000;
# }
# </style>
# <table id="T_bea64">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bea64_level0_col0" class="col_heading level0 col0" >Id</th>
#       <th id="T_bea64_level0_col1" class="col_heading level0 col1" >MSSubClass</th>
#       <th id="T_bea64_level0_col2" class="col_heading level0 col2" >MSZoning</th>
#       <th id="T_bea64_level0_col3" class="col_heading level0 col3" >LotFrontage</th>
#       <th id="T_bea64_level0_col4" class="col_heading level0 col4" >LotArea</th>
#       <th id="T_bea64_level0_col5" class="col_heading level0 col5" >Street</th>
#       <th id="T_bea64_level0_col6" class="col_heading level0 col6" >Alley</th>
#       <th id="T_bea64_level0_col7" class="col_heading level0 col7" >LotShape</th>
#       <th id="T_bea64_level0_col8" class="col_heading level0 col8" >LandContour</th>
#       <th id="T_bea64_level0_col9" class="col_heading level0 col9" >Utilities</th>
#       <th id="T_bea64_level0_col10" class="col_heading level0 col10" >LotConfig</th>
#       <th id="T_bea64_level0_col11" class="col_heading level0 col11" >LandSlope</th>
#       <th id="T_bea64_level0_col12" class="col_heading level0 col12" >Neighborhood</th>
#       <th id="T_bea64_level0_col13" class="col_heading level0 col13" >Condition1</th>
#       <th id="T_bea64_level0_col14" class="col_heading level0 col14" >Condition2</th>
#       <th id="T_bea64_level0_col15" class="col_heading level0 col15" >BldgType</th>
#       <th id="T_bea64_level0_col16" class="col_heading level0 col16" >HouseStyle</th>
#       <th id="T_bea64_level0_col17" class="col_heading level0 col17" >OverallQual</th>
#       <th id="T_bea64_level0_col18" class="col_heading level0 col18" >OverallCond</th>
#       <th id="T_bea64_level0_col19" class="col_heading level0 col19" >YearBuilt</th>
#       <th id="T_bea64_level0_col20" class="col_heading level0 col20" >YearRemodAdd</th>
#       <th id="T_bea64_level0_col21" class="col_heading level0 col21" >RoofStyle</th>
#       <th id="T_bea64_level0_col22" class="col_heading level0 col22" >RoofMatl</th>
#       <th id="T_bea64_level0_col23" class="col_heading level0 col23" >Exterior1st</th>
#       <th id="T_bea64_level0_col24" class="col_heading level0 col24" >Exterior2nd</th>
#       <th id="T_bea64_level0_col25" class="col_heading level0 col25" >MasVnrType</th>
#       <th id="T_bea64_level0_col26" class="col_heading level0 col26" >MasVnrArea</th>
#       <th id="T_bea64_level0_col27" class="col_heading level0 col27" >ExterQual</th>
#       <th id="T_bea64_level0_col28" class="col_heading level0 col28" >ExterCond</th>
#       <th id="T_bea64_level0_col29" class="col_heading level0 col29"

# %%
test.shape
# Out:
# (1459, 80)

# %%
train.dtypes.value_counts()
# Out:
# object     43
# int64      35
# float64     3
# dtype: int64

# %%
train.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageCond        81
# GarageType        81
# GarageFinish      81
# GarageQual        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# Id                 0
# dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.heatmap(train.isnull(), yticklabels=False, cbar=False)
# Out:
# <AxesSubplot:>

# %%
from sklearn.compose import ColumnTransformer
from sklearn.decomposition import PCA
from sklearn.decomposition import TruncatedSVD
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.compose import make_column_transformer
from sklearn.compose import make_column_selector
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score

X = train.drop(['SalePrice', 'Id'], axis=1)
y = train['SalePrice']
test_id = test['Id']
X_predict = test.drop('Id', axis=1)

Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.3)

st = make_column_transformer(
            (
                Pipeline(steps = [
                        ("s1", SimpleImputer(missing_values=np.nan, strategy="median")),
                        ("s2", StandardScaler()),
                       
                ]),                                     make_column_selector(dtype_include=np.number)
            ),
            (
                OneHotEncoder(handle_unknown='ignore'), make_column_selector(dtype_include=object)
            )
        )

        
pipeline = Pipeline(steps = [
    ("scale-transform", st),
    ("svd", TruncatedSVD(150)),
    ("lr", LinearRegression())  
])             
         
#cvs = cross_val_score(pipeline, X, y, cv = 10)
#print(cvs.mean(), cvs.std())

pipeline.fit(Xtrain,ytrain)
train_pred = pipeline.predict(Xtrain)
test_pred = pipeline.predict(Xtest)
print("Train MSE: {}".format(np.sqrt(mean_squared_error(ytrain, train_pred))))
print(f'''train R2={r2_score(ytrain, train_pred)}''')
print("Test MSE: {}".format(np.sqrt(mean_squared_error(ytest, test_pred))))
print(f'''test R2={r2_score(ytest, test_pred)}''')
# Out:
# Train MSE: 26601.928985341114
# train R2=0.8900818340465976
# Test MSE: 28603.046050496894
# test R2=0.8636266510639055

# %%
y_pred = pipeline.predict(X_predict)


submission = pd.DataFrame({
    'Id': test_id,
    'SalePrice': y_pred
})

submission
# Out:
#         Id      SalePrice
# 0     1461  109573.189130
# 1     1462  171382.440158
# 2     1463  194868.301477
# 3     1464  197269.804063
# 4     1465  207633.450185
# ...    ...            ...
# 1454  2915   82584.402411
# 1455  2916   64681.625435
# 1456  2917  166407.899150
# 1457  2918  112223.872228
# 1458  2919  220935.538297
#
# [1459 rows x 2 columns]

# %%
submission.to_csv("submission1.csv", index=False)
